# %%
import os
import google.generativeai as genai

# Set your API key
genai.configure(api_key=GOOGLE_API_KEY)

# Load the Gemini 1.5 Pro model
model = genai.GenerativeModel("gemini-2.5-pro")

# Start a chat session (optional for multi-turn conversations)
chat = model.start_chat()

# Send a test prompt
response = chat.send_message("i load a video to gemini 2.5 pro and i have a failed precondition error, what's the reason?")

# Print the response
print(response.text)
# Out:
# Of course. That's a frustrating error to run into. The "Failed Precondition" error is a common API error that essentially means: **"The state of the system is not right for the request you're trying to make."**
#
# In the context of uploading a video to Gemini 1.5 Pro (the current multimodal model, as of now), it means one or more of the requirements for the video file or your project setup were not met *before* you made the API call.
#
# Here are the most common reasons for this error, broken down into a checklist you can go through.
#
# ---
#
# ### Category 1: The Video File Itself (Most Likely Cause)
#
# This is the most common source of the problem. The model has strict requirements for the media it can process.
#
# 1.  **Unsupported File Format (MIME Type):** Gemini can't process every video codec or container.
#     *   **Supported Formats:** MP4, MPEG, MOV, AVI, FLV, WEBM, WMV.
#     *   **What to do:** Ensure your video is in one of these formats. If you have something like a `.MKV` file, you will need to convert it to a supported format like `.MP4` using a tool like [HandBrake](https://handbrake.fr/) or FFmpeg.
#
# 2.  **File is Too Large:** There are limits to the size of a single file you can upload.
#     *   **The Limit:** The current limit is typically **2GB** per file.
#     *   **What to do:** Check your video's file size. If it's larger than 2GB, you'll need to compress it or use a shorter/lower-resolution clip.
#
# 3.  **File is Corrupted:** The upload might have completed, but the file itself could be unreadable.
#     *   **What to do:** Try playing the video file on your local machine to ensure it's not corrupted. If you uploaded it to Google Cloud Storage, try downloading it back and playing it.
#
# 4.  **Exceeding Total Upload Limits:** While a single file can be 2GB, there might be limits on the total number of files or total data size in a single request.
#     *   **The Limit:** You can typically provide up to 10 files in a single request, with the total size not exceeding 2GB.
#     *   **What to do:** If you are sending multiple files, ensure you are within these limits.
#
# ### Category 2: How You're Providing the File (The Upload Method)
#
# If you're using a service like Vertex AI, you typically upload the video to Google Cloud Storage (GCS) first and then provide the model with a link (a `gs://` URI).
#
# 1.  **Incorrect Google Cloud Storage (GCS) URI:** The path to your file might be wrong.
#     *   **Correct Format:** `gs://your-bucket-name/path/to/your/video.mp4`
#     *   **What to do:** Double-check that the bucket name and the full path to the object are spelled correctly and that there are no typos.
#
# 2.  **GCS Bucket Permissions:** This is a very common "precondition" failure. The Gemini model's service account needs permission to read the file from your GCS bucket.
#     *   **The Problem:** By default, files in GCS are private. The AI model can't access them unless you grant it permission.
#     *   **What to do:** Grant the **"Storage Object Viewer"** role to the service account that Vertex AI uses. You can also make the specific video file public for a quick test, but granting the correct role is the secure, long-term solution.
#
# 3.  **File Not Done Uploading:** You might be sending the API request with the GCS URI *before* the video has actually finished uploading to the bucket. This is a classic race condition.
#     *   **What to do:** Ensure your code waits for the upload to complete successfully before you make the call to the Gemini API.
#
# ### Category 3: Your Project and API Setup
#
# Sometimes the issue isn't the file, but the configuration of your Google Cloud project.
#
# 1.  **APIs Not Enabled:** You must have the correct APIs enabled in your Google Cloud project.
#     *   **Required API:** You need the **"Vertex AI API"** enabled.
#     *   **What to do:** Go to the Google Cloud Console, navigate to "APIs & Services" > "Library", and search for "Vertex AI API". Make sure it is enabled for your project.
#
# 2.  **Billing Not Enabled:** Most Google Cloud services, including Vertex AI, require a billing account to be linked to your project.
#     *   **What to do:** Check the "Billing" section of the Google Cloud Console to ensure your project is linked to an active billing account.
#
# 3.  **Incorrect Location/Region:** You might be trying to make the API call to a region where Gemini 1.5 Pro is not yet available or where your GCS bucket is not located.
#     *   **What to do:** Ensure that your API endpoint and your GCS bucket are in compatible and supported regions (e.g., `us-central1`).
#
# ---
#
# ### How to Troubleshoot: A Step-by-Step Plan
#
# 1.  **Check the File:**
#     *   What is its format? (Is it `.mp4`, `.mov`, etc.?)
#     *   What is its size? (Is it under 2GB?)
#     *   Can you play it locally without errors?
#
# 2.  **Verify the Upload (if using GCS):**
#     *   Log into the Google Cloud Console and navigate to your GCS bucket.
#     *   Can you see the file there?
#     *   Is the name *exactly* the same as in your `gs://` URI?
#     *   Try downloading it from GCS and playing it to confirm it's not corrupted.
#
# 3.  **Check Permissions (if using GCS):**
#     *   As a quick (but insecure) test, select the file in the GCS console, click "Edit access," and add a new principal `allUsers` with the role `Storage Object Viewer`. This makes the file public. **Try your API call again. If it works, you know it's a permission issue.**
#     *   **Remember to remove public access afterwards** and set up the proper IAM permissions for the Vertex AI service account.
#
# 4.  **Review Project Settings:**
#     *   Go to your project's dashboard in Google Cloud.
#     *   Confirm the Vertex AI API is enabled.
#     *   Confirm billing is active.
#
# By systematically checking these points, you will almost certainly find the reason for the "Failed Precondition" error.

# %%
import moviepy

# %%
from moviepy.editor import VideoFileClip
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from moviepy.editor import VideoFileClip
#
# ModuleNotFoundError: No module named 'moviepy.editor'

# %%
from moviepy.editor import VideoFileClip

# Load the original video
video = VideoFileClip("GL010055.mp4")

# Cut the first 5 minutes (5 × 60 = 300 seconds)
trimmed_video = video.subclip(660, 720)

# Save the trimmed video
trimmed_video.write_videofile("video_1_minute_5.mp4", codec="libx264", audio_codec="aac")
# Out:
# Moviepy - Building video video_1_minute_5.mp4.
# MoviePy - Writing audio in video_1_minute_5TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video video_1_minute_5.mp4
# Moviepy - Done !
# Moviepy - video ready video_1_minute_5.mp4

# %%
from google import genai
import time


client = genai.Client(api_key=API_KEY)
print('starting client connection')
myfile = client.files.upload(file="video_1_minute_5.mp4")

while True:
    myfile = client.files.get(name=myfile.name)  # refresh state
    print("Current state:", myfile.state)

    if myfile.state == "ACTIVE":   # processing done
        break
    elif myfile.state == "FAILED":
        raise RuntimeError("File processing failed.")

    time.sleep(5)

print("\nVideo ready!")
print("Save this file ID:", myfile.name)
# Out:
# starting client connection
# Current state: FileState.PROCESSING
# Current state: FileState.ACTIVE
#
# Video ready!
# Save this file ID: files/5btrotiqco50

# %%
response = client.models.generate_content(
    model="gemini-2.0-flash", contents=[myfile, "Tell me the timestamp of a team scoring, be sure that the net moves. It might happen that there is no goal"]
)

print(response.text)
# Out:
# 00:00:21

# %%
response = client.models.generate_content(
    model="gemini-2.0-flash", contents=[myfile, "Tell me the timestamp of a team scoring, be sure that the net moves. It might happen that there is no goal"]
)

print(response.text)
# Out:
# The team scores at [00:00:16].

# %%
response = client.models.generate_content(
    model="gemini-2.0-flash", contents=[myfile, "Tell me the timestamp of a team scoring, be sure that the net moves. It might happen that there is no goal, in that case print []"]
)

print(response.text)
# Out:
# [00:00:17]

# %%
response = client.models.generate_content(
    model="gemini-2.0-flash", contents=[myfile, "Tell me the timestamp of a team scoring, be sure that the net moves. It might happen that there is no goal, in that case print []"]
)

print(response.text)
# Out:
# Sorry, I did not see a team scoring.
